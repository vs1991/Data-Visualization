# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import re
import seaborn as sns 

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor 
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# Column Details
#
#
# 1.Formatted Date= Date & timestamp
# 2. Summary = weather categories
# 3. Temperature (C) = Tempreture
# 4. Apparent Temperature (C) = Tempreture with adding multiple factor like Humidity,Wind speed,Pressure
# 5. Humidity = a quantity representing the amount of water vapour in the atmosphere
# 6. Wind Speed (km/h) = fundamental atmospheric quantity caused by air moving from high to low pressure
# 7. Wind Bearing (degrees) = Wind direction is measured in degrees clockwise from due north
# 8. Visibility (km) = definition of fog is a visibility
# 9. Loud Cover =
# 10. Pressure (millibars) = barometric pressure (after the barometer), is the pressure within the atmosphere of Earth
# 11.Precip Type = the various types of precipitation often include the character or phase of
# the precipitation which is falling to ground level.

# %%
lr=LinearRegression()

# %%
weather=pd.read_csv('weatherHistory.csv')
weather
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
# Formatted Date              96453 non-null object
# Summary                     96453 non-null object
# Precip Type                 95936 non-null object
# Temperature (C)             96453 non-null float64
# Apparent Temperature (C)    96453 non-null float64
# Humidity                    96453 non-null float64
# Wind Speed (km/h)           96453 non-null float64
# Wind Bearing (degrees)      96453 non-null float64
# Visibility (km)             96453 non-null float64
# Loud Cover                  96453 non-null float64
# Pressure (millibars)        96453 non-null float64
# Daily Summary               96453 non-null object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
#import pandas_profiling as pp
#pp.ProfileReport(weather)
weather
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
import datetime as dt
def dated(d):
    return d[0:23]

weather['Formatted Date']=weather['Formatted Date'].apply(dated)
#weather['Formatted Date']=pd.to_datetime(weather['Formatted Date'])

# %%
weather['Formatted Date'] = weather['Formatted Date'].apply(pd.to_datetime)

# %%
weather['Month']=weather['Formatted Date'].dt.month

weather['Year']=weather['Formatted Date'].dt.year

weather['Month']=weather['Month'].replace({1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',
                                           7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'})

# %%
weather['Summary'].value_counts()
#weather['Daily Summary'].value_counts()
weather.head()
# Out:
#        Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-04-01 00:00:00  Partly Cloudy        rain         9.472222
# 1 2006-04-01 01:00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 02:00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 03:00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 04:00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
fig, axs=plt.subplots(ncols=3,figsize=(20,5))
x=weather[weather['Month']=='January']['Summary'].value_counts()
#y=x.sum()/x
sns.barplot((x/x.sum())*100,x.index,ax=axs[0])
axs[0].set_title('Forecast percentage for the month of JANUARY')

sns.barplot((x/x.sum())*100,x.index,ax=axs[1])
axs[1].set_title('Forecast percentage for the month of February')

sns.barplot((x/x.sum())*100,x.index,ax=axs[2])
axs[2].set_title('Forecast percentage for the month of March')

fig, axs=plt.subplots(ncols=3,figsize=(20,5))
x=weather[weather['Month']=='January']['Summary'].value_counts()
#y=x.sum()/x
sns.barplot((x/x.sum())*100,x.index,ax=axs[0])
axs[0].set_title('Forecast percentage for the month of April')

sns.barplot((x/x.sum())*100,x.index,ax=axs[1])
axs[1].set_title('Forecast percentage for the month of May')

sns.barplot((x/x.sum())*100,x.index,ax=axs[2])
axs[2].set_title('Forecast percentage for the month of June')

fig, axs=plt.subplots(ncols=3,figsize=(20,5))
x=weather[weather['Month']=='January']['Summary'].value_counts()
#y=x.sum()/x
sns.barplot((x/x.sum())*100,x.index,ax=axs[0])
axs[0].set_title('Forecast percentage for the month of July')

sns.barplot((x/x.sum())*100,x.index,ax=axs[1])
axs[1].set_title('Forecast percentage for the month of August')

sns.barplot((x/x.sum())*100,x.index,ax=axs[2])
axs[2].set_title('Forecast percentage for the month of September')

fig, axs=plt.subplots(ncols=3,figsize=(20,5))
x=weather[weather['Month']=='January']['Summary'].value_counts()
#y=x.sum()/x
sns.barplot((x/x.sum())*100,x.index,ax=axs[0])
axs[0].set_title('Forecast percentage for the month of October')

sns.barplot((x/x.sum())*100,x.index,ax=axs[1])
axs[1].set_title('Forecast percentage for the month of November')

sns.barplot((x/x.sum())*100,x.index,ax=axs[2])
axs[2].set_title('Forecast percentage for the month of December')
# Out:
# Text(0.5, 1.0, 'Forecast percentage for the month of December')

# %%
sns.pairplot(weather[['Temperature (C)','Apparent Temperature (C)','Humidity','Wind Speed (km/h)',
                     'Wind Bearing (degrees)','Visibility (km)','Pressure (millibars)']])

# %%
plt.figure(figsize=(10,5))
sns.barplot(weather['Summary'].value_counts(),weather['Summary'].value_counts().index)#,shadow=True,autopct='%1.1f%%')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#null values
#filling null value
weather.isnull().sum()
weather['Precip Type'].fillna('Other',inplace=True)

# %%
plt.figure(figsize=(10,5))
plt.pie(weather['Precip Type'].value_counts(),labels=weather['Precip Type'].value_counts().index,shadow=True,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
weather=weather.rename(columns={'Precip Type':'Season'})
weather.head()
# Out:
#        Formatted Date        Summary Season  Temperature (C)  \
# 0 2006-04-01 00:00:00  Partly Cloudy   rain         9.472222
# 1 2006-04-01 01:00:00  Partly Cloudy   rain         9.355556
# 2 2006-04-01 02:00:00  Mostly Cloudy   rain         9.377778
# 3 2006-04-01 03:00:00  Partly Cloudy   rain         8.288889
# 4 2006-04-01 04:00:00  Mostly Cloudy   rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# ...

# %%
fig, axs=plt.subplots(ncols=5,figsize=(14,5))

axs[0].pie(weather[weather['Year']==2006]['Season'].value_counts(),
        labels=weather[weather['Year']==2006]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))  
axs[0].set_title('2006')

axs[1].pie(weather[weather['Year']==2007]['Season'].value_counts(),
        labels=weather[weather['Year']==2007]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))   
axs[1].set_title('2007')

axs[2].pie(weather[weather['Year']==2008]['Season'].value_counts(),
        labels=weather[weather['Year']==2008]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))           
axs[2].set_title('2008')

axs[3].pie(weather[weather['Year']==2009]['Season'].value_counts(),
        labels=weather[weather['Year']==2009]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))
axs[3].set_title('2009')

axs[4].pie(weather[weather['Year']==2010]['Season'].value_counts(),
        labels=weather[weather['Year']==2010]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))
axs[4].set_title('2010')



fig, axs=plt.subplots(ncols=6,figsize=(16,5))

axs[0].pie(weather[weather['Year']==2011]['Season'].value_counts(),
        labels=weather[weather['Year']==2011]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))
axs[0].set_title('2011')

axs[1].pie(weather[weather['Year']==2012]['Season'].value_counts(),
        labels=weather[weather['Year']==2012]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5,0.5))
axs[1].set_title('2012')

axs[2].pie(weather[weather['Year']==2013]['Season'].value_counts(),
        labels=weather[weather['Year']==2013]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))
axs[2].set_title('2013')

axs[3].pie(weather[weather['Year']==2014]['Season'].value_counts(),
        labels=weather[weather['Year']==2014]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))
axs[3].set_title('2014')

axs[4].pie(weather[weather['Year']==2015]['Season'].value_counts(),
        labels=weather[weather['Year']==2015]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5))
axs[4].set_title('2015')

axs[5].pie(weather[weather['Year']==2016]['Season'].value_counts(),
        labels=weather[weather['Year']==2016]['Season'].value_counts().index, autopct='%1.1f%%',
        shadow=True,startangle=45,explode=(0.5,0.5,0.5))
axs[5].set_title('2016')
plt.show()

# %%
#dropping irrelevant columns
weather=weather.drop(['Daily Summary','Loud Cover'],axis=1)
weather.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Season', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
#        'Month', 'Year'],
#       dtype='object')

# %%
#check dtypes of every column
weather.dtypes
# Out:
# Formatted Date              datetime64[ns]
# Summary                             object
# Season                              object
# Temperature (C)                    float64
# Apparent Temperature (C)           float64
# Humidity                           float64
# Wind Speed (km/h)                  float64
# Wind Bearing (degrees)             float64
# Visibility (km)                    float64
# Pressure (millibars)               float64
# Month                               object
# Year                                 int64
# dtype: object

# %%
weather.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       96453.000000            96453.000000     96453.000000
# mean           10.810640              187.509232        10.347325
# std             6.913571              107.383428         4.192123
# min             0.000000                0.000000         0.000000
# ...

# %%
fig, axs=plt.subplots(ncols=3,figsize=(20,4))
sns.distplot(weather['Temperature (C)'],ax=axs[0])
axs[0].axvline(weather['Temperature (C)'].mean(), color='r', linestyle='--', linewidth=1)
axs[0].axvline(weather['Temperature (C)'].median(), color='black', linestyle='--', linewidth=1)
axs[0].axvline(weather['Temperature (C)'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)


sns.distplot(weather['Apparent Temperature (C)'],ax=axs[1])
axs[1].axvline(weather['Apparent Temperature (C)'].mean(), color='r', linestyle='--', linewidth=1)
axs[1].axvline(weather['Apparent Temperature (C)'].median(), color='black', linestyle='--', linewidth=1)
axs[1].axvline(weather['Apparent Temperature (C)'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)


sns.distplot(weather['Humidity'],ax=axs[2])
axs[2].axvline(weather['Humidity'].mean(), color='r', linestyle='--', linewidth=1)
axs[2].axvline(weather['Humidity'].median(), color='black', linestyle='--', linewidth=1)
axs[2].axvline(weather['Humidity'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)




plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.

# %%
fig, axs=plt.subplots(ncols=3,figsize=(20,5))

sns.distplot(weather['Wind Speed (km/h)'],ax=axs[0])
axs[0].axvline(weather['Wind Speed (km/h)'].mean(), color='r', linestyle='--', linewidth=1)
axs[0].axvline(weather['Wind Speed (km/h)'].median(), color='black', linestyle='--', linewidth=1)
axs[0].axvline(weather['Wind Speed (km/h)'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)
axs[0].text(x=50, y=0.093, s = 'mean- ' + str(round(weather['Wind Speed (km/h)'].mean(),2)), color='red')
axs[0].text(x=50, y=0.086, s = 'mode- ' + str(round(weather['Wind Speed (km/h)'].mode().get_values()[0],2)), color='g')
axs[0].text(x=50, y=0.08, s = 'median- ' + str(weather['Wind Speed (km/h)'].median()), color='black')

sns.distplot(weather['Wind Bearing (degrees)'],ax=axs[1])
axs[1].axvline(weather['Wind Bearing (degrees)'].mean(), color='r', linestyle='--', linewidth=1)
axs[1].axvline(weather['Wind Bearing (degrees)'].median(), color='black', linestyle='--', linewidth=1)
axs[1].axvline(weather['Wind Bearing (degrees)'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)
axs[1].text(x=310, y=0.0058, s = 'mean- ' + str(round(weather['Wind Bearing (degrees)'].mean(),2)), color='red')
axs[1].text(x=310, y=0.0054, s = 'mode- ' + str(round(weather['Wind Bearing (degrees)'].mode().get_values()[0],2)), color='g')
axs[1].text(x=310, y=0.0050, s = 'median- ' + str(weather['Wind Bearing (degrees)'].median()), color='black')

sns.distplot(weather['Visibility (km)'],ax=axs[2])
axs[2].axvline(weather['Visibility (km)'].mean(), color='r', linestyle='--', linewidth=1)
axs[2].axvline(weather['Visibility (km)'].median(), color='black', linestyle='--', linewidth=1)
axs[2].axvline(weather['Visibility (km)'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)
axs[2].text(x=0.0, y=0.7, s = 'mean- ' + str(round(weather['Visibility (km)'].mean(),2)), color='red')
axs[2].text(x=0.0, y=0.65, s = 'mode- ' + str(round(weather['Visibility (km)'].mode().get_values()[0],2)), color='g')
axs[2].text(x=0.0, y=0.6, s = 'median- ' + str(weather['Visibility (km)'].median()), color='black')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   app.launch_new_instance()
# ...

# %%
sns.distplot(weather['Pressure (millibars)'])
plt.axvline(weather['Pressure (millibars)'].mean(), color='r', linestyle='--', linewidth=1)
plt.axvline(weather['Pressure (millibars)'].median(), color='black', linestyle='--', linewidth=1)
plt.axvline(weather['Pressure (millibars)'].mode().get_values()[0], color='g', linestyle='--', linewidth=1)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   after removing the cwd from sys.path.

# %%
#boxplot for each variables

fig, axs=plt.subplots(ncols=4,figsize=(25,4))
sns.boxplot(weather['Temperature (C)'],ax=axs[0])
sns.boxplot(weather['Apparent Temperature (C)'],ax=axs[1])
sns.boxplot(weather['Humidity'],ax=axs[2])
sns.boxplot(weather['Wind Speed (km/h)'],ax=axs[3])



fig, axs=plt.subplots(ncols=3,figsize=(25,4))
sns.boxplot(weather['Wind Bearing (degrees)'],ax=axs[0])
sns.boxplot(weather['Visibility (km)'],ax=axs[1])
sns.boxplot(weather['Pressure (millibars)'],ax=axs[2])
plt.show()

# %%
#viloin plot for temperatures various season 
plt.figure(figsize=(10,6))
#sns.set_style("whitegrid")
sns.set_style("darkgrid")
ax=sns.violinplot(x='Season', y='Temperature (C)', data=weather)

# %%
#correlation coeffecient 
c=weather.corr()

#print('*'*60)
ax=sns.heatmap(c,linewidths=.5,annot=True)
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(20,6))
#sns.set_style("whitegrid")
sns.set_style("darkgrid")
ax=sns.violinplot(x='Month', y='Temperature (C)', data=weather)

# %%
plt.figure(figsize=(20,6))
sns.violinplot(x='Year', y='Temperature (C)', data=weather)

# %%
month_year=weather[['Month','Year','Temperature (C)','Season']]

plt.figure(figsize=(10,5))
sns.barplot(x=month_year['Season'], y=month_year['Temperature (C)'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=month_year['Month'], y=month_year['Temperature (C)'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(weather['Month'],weather['Temperature (C)'],linewidth=0.05)#,order=['January','February','March','April','May','June','July','August','September','October','November','December'])
weather.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Season', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
#        'Month', 'Year'],
#       dtype='object')

# %%
weather[weather['Month']=='July']['Temperature (C)'].min()
# Out:
# 7.950000000000001

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x='Month', y='Temperature (C)',data=weather,palette="muted", split=True,order=['Jan','February','March','April',
'May','June','July','August','September','October','November','December'])#,inner='quartile')

# %%
weather.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Season', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
#        'Month', 'Year'],
#       dtype='object')

# %%
plt.figure(figsize=(20,12))
ax=sns.stripplot(x='Year', y='Temperature (C)',hue='Season',data=weather,jitter=0.05, linewidth=0.3),#order=['January','February','March','April',
#'May','June','July','August','September','October','November','December'],palette="Set2")#,size=20, marker="D", edgecolor="gray", alpha=.25)
ax=sns.violinplot(x='Year', y='Temperature (C)',data=weather)#,inner='quartile')

# %%
weather.groupby(['Apparent Temperature (C)','Temperature (C)']).size().reset_index(name='Count')
# Out:
#        Apparent Temperature (C)  Temperature (C)  Count
# 0                    -27.716667       -20.000000      1
# 1                    -26.227778       -20.000000      1
# 2                    -25.922222       -20.555556      1
# 3                    -25.200000       -20.050000      1
# 4                    -25.072222       -20.277778      1
# ...                         ...              ...    ...
# 41650                 38.255556        37.072222      1
# 41651                 38.377778        36.972222      1
# 41652                 38.416667        37.872222      1
# 41653                 38.661111        37.266667      1
# 41654                 39.344444        34.955556      1
#
# [41655 rows x 3 columns]

# %%
weather['Time']=weather['Formatted Date'].dt.time
sns.regplot(weather['Humidity'],weather['Apparent Temperature (C)'])

# %% [markdown]
# Topics
# 1.Histogram[-univariate-]
# 2.Pie plot [-univariate-(categorical value-]
# 3.Scatter plot[-bivariate-]
# 4.Measure of Center
# 5.Measure of dispersion[mean-std,]
# 6.Distribution(normal-mean mode median would be the same)
# 7.Correlation(z**2 to check how many std away from my mean )
# 8.Covariance(only gives u the direction doesnt show strength)

# %% [markdown]
# # how to check normal distribution
# 1.skewness
# fisher pearson skewness formula summation:-((y-ymean)**3/N)/s**3 if less than 0 skewness left,if more than 0 skewness right
# 2.shapiro-test for normality
# 3.kurtosis((y-ymean)**4)/N)/s**3(if normally distributed it will come to 3)
# Galtan Skewness (q1+q3-2q2)/q3-q1

# %%
for univariate ananlysise include the following data
1.histogram or boxplot
2.summary stats(mean,median,q1,q3,min,max,skewness score,shapiro or 
                normality test to determine wether distribution is normal or not normal)


QQ include below

1.scatterplot
2.pearson coeff
3.lineplot using SLR and value of r2
# Out:
#   File "<ipython-input-37-0e064f14280d>", line 1
#     for univariate ananlysise include the following data
#                             ^
# SyntaxError: invalid syntax

# %%
create a function for 
numeric univariate
--histogram with metadata

for qq
--scatterplot + line regression

# %%
from scipy.stats import shapiro
from scipy import stats

# %%
def univar_analys(a):
    
    print('Mean value:',a.mean())
    print('Median value:',a.median())
    print('Standard deviation:',a.std())
    print('Mode value:',a.median())
    print('Q1:',a.quantile(0.25))
    print('Q3:',a.quantile(0.75))
    print('Minimum:',a.min())
    print('Maximum:',a.max())
    print('Skewness:',a.skew())
    print('Shapriro test:',shapiro(a))
    print('Normal test:',stats.normaltest(a))
    print('Kurtosis:',a.kurtosis())
    
    if a.skew()>1.5:
        print('Positively skewed')
    else:
        print('Negatively skewed')
    
    plt.figure(figsize=(20,5))
    sns.distplot(a,bins=int((96453)**0.33)*2)
    plt.axvline(a.mean(), color='r', linestyle='--', linewidth=1)
    plt.axvline(a.median(), color='black', linestyle='--', linewidth=1)
    plt.axvline(a.mode().get_values()[0], color='g', linestyle='--', linewidth=1)

    
    return

# %%
weather[weather['Pressure (millibars)']>0]['Pressure (millibars)']

# %%
weather

# %%
univar_analys(weather[weather['Pressure (millibars)']>0]['Pressure (millibars)'])

# %%
def bivar_analys(a,b):
    print('Pearson Corelation Coeff:',a.corr(b))
    
    plt.figure(figsize=(20,5))
    sns.scatterplot(a,b)
    
    
    return

# %%
bivar_analys(weather['Temperature (C)'],weather['Humidity'])

# %%
univar_analys(weather['Temperature (C)'])

# %%
stats.normaltest(weather['Temperature (C)'])

# %%
univar_analys(weather['Humidity'])

# %%
weather.corr()

# %%
# generate gaussian data
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
# seed the random number generator
seed(1)
# generate univariate observations
data = 5 * randn(100) + 50
# summarize
print('mean=%.3f stdv=%.3f' % (mean(data), std(data)))

# %%
seed(1)
# generate univariate observations
data = 5 * randn(100) + 50
# histogram plot
plt.hist(data)
plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot
data = 5 * randn(100) + 50
# q-q plot
qqplot(data, line='s')
plt.show()

# %%
stat, p = shapiro(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')

# %%
shapiro(weather[weather['Pressure (millibars)']>0]['Pressure (millibars)'])

# %%
import random
import pandas as pd
import numpy as np
x = [random. randint(1,100) for x in range(200)]
y=[random. randint(1,200) for x in range(200)]
df=pd.DataFrame({'random1':x,'random2':y})

# %%
df['random1'].value_counts()
# Out:
# 28     7
# 20     5
# 70     5
# 71     5
# 35     5
#       ..
# 83     1
# 34     1
# 26     1
# 86     1
# 100    1
# Name: random1, Length: 89, dtype: int64

# %%
X=np.array(list(zip(f_1b,f_2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-dce7c563ca28> in <module>
# ----> 1 X=np.array(list(zip(f_1,f_2)))
#
# NameError: name 'f_1' is not defined

# %%
def dist(a,b,ax=1):
    return np.linalg.norm(a-b,axis=ax)

# %%
C_x = np.random.randint(0, np.max(X)-20, size=k)
C_y = np.random.randint(0, np.max(X)-20, size=k)
# Out:
# array([170,  61,  59])

# %%
np.max(X)-20
# Out:
# 180

# %%
C_y
# Out:
# array([145, 121,  48])

# %%
(np.arange(9)-9).reshape(3,3)
# Out:
# array([[-9, -8, -7],
#        [-6, -5, -4],
#        [-3, -2, -1]])
